# %%
import cv2
import pytesseract
import io

from pyforest import *
from PIL import Image, ImageFilter
from skimage import color

# %%
image = Image.open('quote.jpg')

# %%
plt.imshow(image)

# %%
text = pytesseract.image_to_string(image, lang = 'eng')

# %%
text
# Out:
# 'Eleanor Roosevelt\n\na Brainy Quote'

# %%
image2 = Image.open('dandruce.jpg')
text2 = pytesseract.image_to_string(image2, lang = 'eng')
text2
# Out:
# 'A NIGHT OF CLASS MUSIC FOR DANCING WITH PALS IN AID OF CHARITY.\nAS eC — —\n& FS i i\n,\n\ny\n\n \n\nNaa sats\nALL PROCEEDS DONATED\nTO CAPABILITY SCOTLAND\n\nADVANCE TICKETS AVAILABLE WITH A DONATION TO\nWWW.JUSTGIVING.COM/FUNDRAISING/DAN-JUICE'

# %%
plt.imshow(image2)

# %%
image = image.filter(ImageFilter.GaussianBlur(1))

# %%
print(text)
# Out:
# Eleanor Roosevelt
#
# a Brainy Quote
